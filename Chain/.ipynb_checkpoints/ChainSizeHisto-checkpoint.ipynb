# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib
from pylab import *

# %%
# Setting plot style
# Print available styles

# print(plt.style.available)


# matplotlib.style.use('ggplot')
matplotlib.style.use('seaborn-ticks')

# %%
# Reading data from CSV file and putting workload name as index column
data = pd.read_csv('/home/amirali/git/plotpython/Data/chain_size_histo.csv', index_col='workload')
data.columns.values
# Out:
# array(['function', '1', '2', '3', '4', '5', 'Unnamed: 7'], dtype=object)

# %%
# Selecting columns 
n = data.loc[:,['1','2','3','4','5']]
n.columns = ['1','2','3','4','5+']

# %%
# Ploting the bar chart
n.plot(kind='bar', stacked=True)
# Out:
# <img src="data:image/png;base64,...">

# %%
print(plt.style.available)
# Out:
# ['seaborn-white', 'seaborn-colorblind', 'seaborn-ticks', 'dark_background', 'seaborn-notebook', 'seaborn-muted', 'classic', 'seaborn-whitegrid', 'fivethirtyeight', 'seaborn-poster', 'seaborn-pastel', 'seaborn-deep', 'grayscale', 'seaborn-bright', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-paper', 'seaborn-talk', 'seaborn-dark-palette', 'bmh', 'ggplot']
