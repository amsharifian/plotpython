# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib
from pylab import *

# %%
# Setting plot style
# Print available styles

# print(plt.style.available)

matplotlib.style.use('seaborn-ticks')

# %%
# Reading data from CSV file and putting workload name as index column
data = pd.read_csv('/home/amirali/git/plotpython/Data/avg_chain_length.csv', index_col='workload')
data.columns.values
# Out:
# array(['function', 'ilp', 'merge'], dtype=object)

# %%
# Selecting columns 
n = data.loc[:,['ilp','merge']]
n.columns = ['Max ILP', 'Max size']

# %%
# Ploting the bar chart
ax = n.plot(kind='barh', width=0.8, color = ['#bdbdbd','#444444'],fontsize=15)

# Adding grid lines
ax.xaxis.grid()

# Setting X and Y labels
ax.set_xlabel("")
ax.set_ylabel("Average Chain Length", fontsize=20)

# Making plot tight
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print(plt.style.available)
# Out:
# ['seaborn-paper', 'seaborn-deep', 'grayscale', 'seaborn-whitegrid', 'fivethirtyeight', 'seaborn-dark-palette', 'seaborn-white', 'classic', 'seaborn-ticks', 'seaborn-talk', 'seaborn-darkgrid', 'ggplot', 'bmh', 'seaborn-bright', 'seaborn-pastel', 'seaborn-colorblind', 'dark_background', 'seaborn-notebook', 'seaborn-poster', 'seaborn-dark', 'seaborn-muted']
