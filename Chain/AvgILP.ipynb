# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib
from pylab import *

# %%
# Setting plot style
# Print available styles

# print(plt.style.available)

matplotlib.style.use('seaborn-ticks')

# %%
# Reading data from CSV file and putting workload name as index column
data = pd.read_csv('/home/amirali/git/plotpython/Data/avg_ilp.csv', index_col='workload')
data.columns.values
# Out:
# array(['function', 'merge', 'ilp', 'graph'], dtype=object)

# %%
# Selecting columns 
n = data.loc[:,['graph','ilp','merge']]
n.columns = ['Unchained', 'Max ILP', 'Max size']

# %%
# Ploting the bar chart
ax = n.plot(kind='bar', width=0.8, fontsize=15)

# Adding grid lines
ax.yaxis.grid()

# Setting X and Y labels
ax.set_xlabel("")
ax.set_ylabel("Average ILP", fontsize=20)

# Making plot tight
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print(plt.style.available)
# Out:
# ['seaborn-white', 'seaborn-colorblind', 'seaborn-ticks', 'dark_background', 'seaborn-notebook', 'seaborn-muted', 'classic', 'seaborn-whitegrid', 'fivethirtyeight', 'seaborn-poster', 'seaborn-pastel', 'seaborn-deep', 'grayscale', 'seaborn-bright', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-paper', 'seaborn-talk', 'seaborn-dark-palette', 'bmh', 'ggplot']
