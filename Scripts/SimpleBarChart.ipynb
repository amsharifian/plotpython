# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib
from pylab import *

# %%
# Setting plot style
matplotlib.style.use('ggplot')

# %%
# Reading data from CSV file and putting workload name as index column
data = pd.read_csv('mlp_data.csv', index_col='workload')

# %%
# Selecting columns 
n = data.loc[:,['num_ch','ILP']]
n.columns = ['Number of Chains', 'ILP']
n
# Out:
#                         Number of Chains       ILP
# workload
# 164.gzip.dfg                          29   5.80000
# 175.vpr.dfg                           29   4.83333
# 179.art.dfg                           19   3.16667
# 181.mcf.dfg                           11   2.20000
# 183.equake.dfg                       127  11.54550
# 186.crafty.dfg                        29   4.14286
# 197.parser.dfg                        48   1.84615
# 401.bzip2.dfg                         26   3.71429
# 403.gcc.dfg                            8   2.66667
# 429.mcf.dfg                           11   2.20000
# 444.namd.dfg                          32   4.57143
# 450.soplex.dfg                        23   3.28571
# 453.povray.dfg                        34   3.77778
# 456.hmmer.dfg                         94  15.66670
# 458.sjeng.dfg                         70   5.83333
# 464.h264ref.dfg                       34   3.40000
# 470.lbm.dfg                          105  21.00000
# 482.sphinx3.dfg                       29   5.80000
# blackscholes.dfg                      24   3.42857
# bodytrack.dfg                         19   9.50000
# dwt53.dfg                             34   3.77778
# ferret.dfg                            26   8.66667
# fft-2d.dfg                            40   4.00000
# fluidanimate.dfg                      13   3.25000
# freqmine.dfg                          38   6.33333
# sar-backprojection.dfg                 7   1.75000
# sar-pfa-interp1.dfg                   17   4.25000
# streamcluster.dfg                     17   4.25000

# %%
# Ploting the bar chart
n.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,...">
