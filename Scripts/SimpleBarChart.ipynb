# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib
from pylab import *

# %%
# Setting plot style
matplotlib.style.use('ggplot')

# %%
# Reading data from CSV file and putting workload name as index column
data = pd.read_csv('mlp_data.csv', index_col='workload')

# %%
# Selecting columns bas on their integer location (Selecting by label didn't work)
n = data.iloc[:,[6,7]]
# Out:
# <img src="data:image/png;base64,...">

# %%
# Ploting the bar chart
n.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,...">
